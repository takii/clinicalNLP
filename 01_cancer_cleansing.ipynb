# %% [markdown]
# # Data Cleansing
#
# * 라벨링 제거

# %% [markdown]
# ## Data 불러오기

# %%
import pandas as pd

# %%
data = pd.read_csv('rawdata/lung_cancer.csv')
data.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0    17  NCT01376856  Characteristics of Mediastinal Lymph Node With...
# 1    19  NCT01310387  Prospective Study of Active Pain Management in...
# 2    27  NCT03394703               Korean Lung Cancer Screening Project
# 3    46  NCT01441297  BIBF 1120 as Second Line Treatment for Small C...
# 4    59  NCT00736814  First-Line Combination Chemotherapy in Treatin...
#
#    Acronym          Status         Study Results  \
# 0      NaN      Terminated  No Results Available
# 1      APM       Completed  No Results Available
# 2  K-LUCAS  Unknown status  No Results Available
# 3      NaN       Completed  No Results Available
# 4      NaN  Unknown status  No Results Available
#
#                                           Conditions  \
# 0                                        Lung Cancer
# 1                                        Lung Cancer
# 2                                        Lung Cancer
# 3  Small Cell Lung Cancer|Small Cell Lung Cancer ...
# 4                                        Lung Cancer
#
#                                        Interventions  \
# 0                                                NaN
# 1                 Behavioral: Active pain management
# 2                                                NaN
# 3                                    Drug: BIBF 1120
# 4  Drug: carboplatin|Drug: docetaxel|Drug: gemcit...
#
#                                     Outcome Measures  \
# 0      false positive rate of Mediastinal Lymph Node
# 1  The percent of pain intensity difference|Patie...
# 2  Early stage lung cancer detection rate|False p...
# 3  Overall response rate|Overall survival rate|Pr...
# 4  Response rate (complete and partial responses)...
#
#                                Sponsor/Collaborators  ...  \
# 0                                  Yonsei University  ...
# 1  Chonnam National University Hospital|Janssen K...  ...
# 2  National Cancer Center, Korea|Korean Associati...  ...
# 3          Ji-youn Han|National Cancer Center, Korea  ...
# 4  Yonsei University|National Cancer Institute (NCI)  ...
#
#   Primary Completion Date Completion Date First Posted  Results First Posted  \
# 0                  Nov.11          Nov.11    20.Jun.11                   NaN
# 1                  Jan.12          Jun.12     8.Mar.11                   NaN
# 2               31.Dec.17       31.Dec.18     9.Jan.18                   NaN
# 3               31.Oct.15       31.Mar.16    27.Sep.11                   NaN
# 4                     NaN             NaN    18.Aug.08                   NaN
#
#   Last Update Posted                                          Locations  \
# 0           4.Jun.13      Severance Hospital, Seoul, Korea, Republic of
# 1           5.Feb.16  Chonnam National University Hwasun Hospital, J...
# 2           9.Jan.18  National Cancer Center, Goyang, Gyeonggi, Kore...
# 3          25.Aug.17  National Cancer Center, Goyang-si, Gyeonggi-do...
# 4          24.Feb.11  Yonsei Cancer Center at Yonsei University Medi...
#
#   Study Documents                                          URL  \
# 0             NaN  https://ClinicalTrials.gov/show/NCT01376856
# 1             NaN  https://ClinicalTrials.gov/show/NCT01310387
# 2             NaN  https://ClinicalTrials.gov/show/NCT03394703
# 3             NaN  https://ClinicalTrials.gov/show/NCT01441297
# 4             NaN  https://ClinicalTrials.gov/show/NCT00736814
#
#                                   Inclusion Criteria  \
# 0  1. age 20-75, men and women\n2. person who per...
# 1  1. Outpatients with lung cancer.\n2. The patie...
# 2  Inclusion Criteria (1)\n1. Age : 55-74 years o...
# 3  1. Histologically confirmed SCLC\n2. Progressi...
# 4  DISEASE CHARACTERISTICS:\n1. Histologically pr...
#
#                                   Exclusion Criteria
# 0  1. age < 20\n2. person who don't agree with en...
# 1  1. Drug or alcohol abusers.\n2. Child-bearing ...
# 2  1. Lung cancer diagnosed and treated\n2. Inabi...
# 3  1. Previous therapy with other VGFR inhibitors...
# 4                                                NaN
#
# [5 rows x 29 columns]

# %%
print(f'데이터 갯수 {data.shape[0]}')
# Out:
# 데이터 갯수 459

# %% [markdown]
# ## Criteria 형식 변경
#
# > ordered list를 개행문자 단위로 쪼개기
#
# * NaN 예외처리 => 빈 문자열
#
# * 아래의 예시 상황의 경우 하나의 문장으로 패턴 일치화
#
# ```
# DISEASE CHARACTERISTICS:
# 1. Histologically confirmed invasive breast cancer
# 1) Stage II or III disease
# 2) No evidence of metastasis (M0)
# 3) No inflammatory breast cancer (T4d)
# ```
#
# * 아래의 예시 상황의 경우 문장에서 제외 (미반영)
#
# ```
# DISEASE CHARACTERISTICS:
# 1. Histologically confirmed invasive breast cancer
# ```

# %%
creteria = data[['Inclusion Criteria', 'Exclusion Criteria']]
print(f'데이터 갯수 {creteria.shape[0]}')

# NaN 빈 텍스트 치환
creteria.fillna(value='')

creteria
# Out:
# 데이터 갯수 459
#                                     Inclusion Criteria  \
# 0    1. age 20-75, men and women\n2. person who per...
# 1    1. Outpatients with lung cancer.\n2. The patie...
# 2    Inclusion Criteria (1)\n1. Age : 55-74 years o...
# 3    1. Histologically confirmed SCLC\n2. Progressi...
# 4    DISEASE CHARACTERISTICS:\n1. Histologically pr...
# ..                                                 ...
# 454  1. Pathologically confirmed stage IIIB/IV aden...
# 455  1. Male or female patients aged 20 years or ol...
# 456  1. Eligible for, or on active study drug treat...
# 457  1. Pathologically confirmed diagnosis of Stage...
# 458  1. Age ≥ 18\n2. ECOG Performance Status of 0 o...
#
#                                     Exclusion Criteria
# 0    1. age < 20\n2. person who don't agree with en...
# 1    1. Drug or alcohol abusers.\n2. Child-bearing ...
# 2    1. Lung cancer diagnosed and treated\n2. Inabi...
# 3    1. Previous therapy with other VGFR inhibitors...
# 4                                                  NaN
# ..                                                 ...
# 454  1. More than two prior cytotoxic chemotherapy ...
# 455  1. Prior systemic chemotherapy, immunotherapy ...
# 456  1. History of hypersensitivity to the active s...
# 457  1. Prior chemotherapy for relapsed and/or meta...
# 458  1. Receipt of an EGFR TKI within 14 days of th...
#
# [459 rows x 2 columns]

# %% [markdown]
# ### 정규식 및 텍스트 처리
#
# 1. 정규식
#
#     * `숫자.` 을 기준으로 split
#
#     * 좌측 공백 제거, 우측 공백 유지(\n)
#
# 2. 텍스트 처리
#
#     * 좌측 공백/개행 제거, 우측 개행 유지(\n)
#
#     * 이후 한 문장으로 변환

# %%
import re

# %%
# 예시
text = '''
DISEASE CHARACTERISTICS:
1. Histologically confirmed invasive breast cancer
1) Stage II or III disease
2) No evidence of metastasis (M0)
2. Must have a primary tumor
3. Operable disease
4. Triple-negative disease, meeting the following criteria:
1) Estrogen receptor-, progesterone receptor-, and HER2-negative by immunohistochemistry (IHC) 0 or 1+ OR fluorescence in situ hybridization negative (in case IHC is 2+)
PATIENT CHARACTERISTICS:
5. ECOG performance status 0-1
'''
# 문장 구분
print(list(map(lambda x: x.lstrip(), re.split('\d[.]', text))))

# Text 변환
print(''.join(map(lambda x: x.lstrip(), re.split('\d[.]', text))))
# Out:
# ['DISEASE CHARACTERISTICS:\n', 'Histologically confirmed invasive breast cancer\n1) Stage II or III disease\n2) No evidence of metastasis (M0)\n', 'Must have a primary tumor\n', 'Operable disease\n', 'Triple-negative disease, meeting the following criteria:\n1) Estrogen receptor-, progesterone receptor-, and HER2-negative by immunohistochemistry (IHC) 0 or 1+ OR fluorescence in situ hybridization negative (in case IHC is 2+)\nPATIENT CHARACTERISTICS:\n', 'ECOG performance status 0-1\n']
# DISEASE CHARACTERISTICS:
# Histologically confirmed invasive breast cancer
# 1) Stage II or III disease
# 2) No evidence of metastasis (M0)
# Must have a primary tumor
# Operable disease
# Triple-negative disease, meeting the following criteria:
# 1) Estrogen receptor-, progesterone receptor-, and HER2-negative by immunohistochemistry (IHC) 0 or 1+ OR fluorescence in situ hybridization negative (in case IHC is 2+)
# PATIENT CHARACTERISTICS:
# ECOG performance status 0-1

# %%
def parse_text(text):
    if pd.isna(text):
        return ''
    return ''.join(map(lambda x: x.lstrip(), re.split('\d[.]', text)))

# %%
clean_creteria = creteria.applymap(parse_text)
print(creteria.shape[0])
clean_creteria
# Out:
# 459
#                                     Inclusion Criteria  \
# 0    age 20-75, men and women\nperson who performed...
# 1    Outpatients with lung cancer.\nThe patients wi...
# 2    Inclusion Criteria (1)\nAge : 55-74 years old\...
# 3    Histologically confirmed SCLC\nProgression dur...
# 4    DISEASE CHARACTERISTICS:\nHistologically prove...
# ..                                                 ...
# 454  Pathologically confirmed stage IIIB/IV adenoca...
# 455  Male or female patients aged 20 years or older...
# 456  Eligible for, or on active study drug treatmen...
# 457  Pathologically confirmed diagnosis of Stage II...
# 458  Age ≥ 18\nECOG Performance Status of 0 or 1\nW...
#
#                                     Exclusion Criteria
# 0    age < 20\nperson who don't agree with enrollme...
# 1    Drug or alcohol abusers.\nChild-bearing women ...
# 2    Lung cancer diagnosed and treated\nInability t...
# 3    Previous therapy with other VGFR inhibitors (o...
# 4
# ..                                                 ...
# 454  More than two prior cytotoxic chemotherapy tre...
# 455  Prior systemic chemotherapy, immunotherapy or ...
# 456  History of hypersensitivity to the active subs...
# 457  Prior chemotherapy for relapsed and/or metasta...
# 458  Receipt of an EGFR TKI within 14 days of the f...
#
# [459 rows x 2 columns]

# %% [markdown]
# ## Export csv

# %%
clean_creteria.to_csv('result/cleaned_lung_cancer.csv')
